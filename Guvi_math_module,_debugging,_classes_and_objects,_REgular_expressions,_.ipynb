# %% [markdown]
# <a href="https://colab.research.google.com/github/sridevibonthu/testdw56/blob/main/Guvi_math_module%2C_debugging%2C_classes_and_objects%2C_REgular_expressions%2C_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
math.pow(4,5)
# Out:
# 1024.0

# %%
math.sqrt(9.9)
# Out:
# 3.146426544510455

# %%
math.ceil(8.1)
# Out:
# 9

# %%
math.floor(8.1)
# Out:
# 8

# %%
abs(-8)
# Out:
# 8

# %%
import math as m  #create an alias

# %%
m.sqrt(8)
# Out:
# 2.8284271247461903

# %%
from math import sqrt  #import s only sqrt function

# %%
sqrt(4)
# Out:
# 2.0

# %% [markdown]
# #learn about random module

# %%
math.trunc(8.9)

# %%
round(8.6)

# %%
#Learn about random module, os module

# %%
def sumofn(n):
  sum = 0
  for i in range(1, n+1):
    sum = sum + i
    #print(i, sum)

  return(sum)

# %%
sumofn(10)
# Out:
# 55

# %%
sumofn(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f3b150fc80b7> in <module>
# ----> 1 sumofn(10)
#
# NameError: name 'sumofn' is not defined

# %% [markdown]
# #Debugging in python

# %% [markdown]
# Google Colab allows you to directly create a Notebook and run algorithms on GPU (if you are doing Machine Learning) instead of having to deal with Jupyter or driver installations etc.
#
# What is missing here when compared with regular IDEs?
#
# a debugger.

# %% [markdown]
# can always use print() as a quick substitute for debugger but sometimes you need to explore the problem more in the state it occurred, learn how the program is being executed etc.

# %% [markdown]
# ipdb is the python debugger meant for debugging in jupyter notebooks

# %%
pip install ipdb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 784.3/784.3 KB 23.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.4/386.4 KB 38.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 2.0.10
#     Uninstalling prompt-toolkit-2.0.10:
#       Successfully uninstalled prompt-toolkit-2.0.10
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.9.0
#     Uninstalling ipython-7.9.0:
#       Successfully uninstalled ipython-7.9.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython~=7.9.0, but you have ipython 8.10.0 which is incompatible.
# ...

# %%
import ipdb

# %%
#turn on debugging
#whenever your code hits into an Exception, the code will pause and the debugger view will be opened 
#for you to explore what caused the exception
# %pdb on
# Out:
# Automatic pdb calling has been turned ON

# %%
def fib(n):
  if n <= 1:
    return n
  arr = [0, 1]
  for i in range(2, n+1):
    arr.append(arr[i-1] + arr[i-2])
  return arr[n]

# %%
fib(6)
# Out:
# 8

# %%
def fib(n):
  if n <= 1:
    return n
  arr = [0, 1]
  for i in range(2, n+1):
    arr.append(arr[i-1] + arr[i-2])
  return arr[n+1]

# %%
fib(4)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-252d5fa3ed3f> in <module>
# ----> 1 fib(4)
#
# <ipython-input-16-a1ad9ce58a0a> in fib(n)
#       5   for i in range(2, n+1):
#       6     arr.append(arr[i-1] + arr[i-2])
# ----> 7   return arr[n+1]
#
# IndexError: list index out of range
# > <ipython-input-16-a1ad9ce58a0a>(7)fib()
#       3     return n
#       4   arr = [0, 1]
#       5   for i in range(2, n+1):
#       6     arr.append(arr[i-1] + arr[i-2])
# ----> 7   return arr[n+1]
#
# ipdb> arr
# [0, 1, 1, 2, 3]
# ipdb> i
# 4
# ipdb> arr[i]
# 3
# ipdb> arr[n]
# 3
# ipdb> arr[n+1]
# *** IndexError: list index out of range
# ipdb> n

# %%
# %pdb off
# Out:
# Automatic pdb calling has been turned OFF

# %%
# %pdb on

# %%
def fib(n):
  if n <= 1:
    return n
  arr = [0, 1]
  for i in range(2, n+1):
    
    arr.append(arr[i-1] + arr[i-2])
    ipdb.set_trace()
  return arr[n]

# %%
fib(5)

# %% [markdown]
# #Class and Objects

# %% [markdown]
# How to define a class in Python?

# %%
class test:
  pass

# %%
class Person:
  x = 10
  
  def greet(self):
    print("Hello")

# %%
print(Person.x)
# Out:
# 10

# %%
Person.greet()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-95d585d6b96f> in <cell line: 1>()
# ----> 1 Person.greet()
#
# TypeError: Person.greet() missing 1 required positional argument: 'self'

# %%
# %pdb off

# %%
#Creating objects
ram = Person()

# %%
type(ram)
# Out:
# __main__.Person

# %%
ram.x
# Out:
# 10

# %%
ram.greet()

# %%
sita = Person()

# %%
sita.greet()

# %%
sita.x

# %% [markdown]
# What is this self parameter?
#
# whenever an object calls its method, the object itself is passed as the first argument. So, ram.greet() translates into Person.greet(ram)

# %%
class student:
  branch = 'CSE'

  def set_details(self, rno, name):
    self.rno = rno
    self.name = name
  
  def print_details(self):
    print(f'Regd no : {self.rno}')
    print(f'Name : {self.name}')
    print(f'Branch : {student.branch}')

# %%
s1 = student()

# %%
s1.branch
# Out:
# 'CSE'

# %%
s1.set_details('567', 'sairam')

# %%
s1.print_details()
# Out:
# Regd no : 567
# Name : sairam
# Branch : CSE

# %%
s2 = student()
s2.set_details(78, 'krishna')
s2.print_details()
# Out:
# Regd no : 78
# Name : krishna
# Branch : CSE

# %%
class student:
  branch = 'CSE'

  def __init__(self, rno, name):
    self.rno = rno
    self.name = name
    
  def set_details(self, rno, name):
    self.rno = rno
    self.name = name
  
  def print_details(self):
    print(f'Regd no : {self.rno}')
    print(f'Name : {self.name}')
    print(f'Branch : {student.branch}')

# %%
s3 = student(67, 'ram')

# %%
s3.print_details()
# Out:
# Regd no : 67
# Name : ram
# Branch : CSE

# %% [markdown]
# ###constructors
#
# Class functions that begin with double underscore __ are called special functions as they have special meaning.
#
# Of one particular interest is the \_\_init\_\_() function. This special function gets called whenever a new object of that class is instantiated.
#
# This type of function is also called constructors in Object Oriented Programming (OOP). We normally use it to initialize all the variables.

# %%
a=10
print("a=",a)
print(f'a = {a} ha ha')

# %%
class Student:
  def __init__(self, num, name):
    self.num = num
    self.name = name
  def get_data(self):
    print(f'Number : {self.num}, Name : {self.name}')

# %%
s1 = Student(501, "sai")
s2 = Student(502, 'ram')

# %%
type(s1)

# %%
s1.get_data()

# %%
s2.get_data()

# %%
del s2

# %%
s2.get_data()

# %%
s1.get_data()

# %%
#deleting attributes and objects
del s1.num

# %%
s1.get_data()

# %% [markdown]
# #Regular Expressions

# %% [markdown]
# A Regular Expression (RegEx) is a sequence of characters that defines a search pattern.

# %% [markdown]
# What does the following pattern means?
#
# ^a...s$

# %% [markdown]
# Python has a module named re to work with RegEx. Here's an example:

# %%
import re

pattern = '^a...s$'
test_string = input("Enter a string")
result = re.match(pattern, test_string)

if result:
  print("Search successful.")
else:
  print("Search unsuccessful.")
# Out:
# Enter a string4
# Search unsuccessful.

# %% [markdown]
# To specify regular expressions, **metacharacters** are used. In the above example, ^ and $ are metacharacters.
#
# Metacharacters are characters that are interpreted in a special way by a RegEx engine. Here's a list of metacharacters:
#
# [ ] . ^ $ * + ? { } ( ) \ |

# %% [markdown]
# [ ] - Square brackets
#
# Square brackets specifies a set of characters you wish to match.
#
# You can also specify a range of characters using - inside square brackets. [a-e] is the same as [abcde].
#
# You can complement (invert) the character set by using caret ^ symbol at the start of a square-bracket. [^abc] means any character except a or b or c.

# %%
if re.match('[^abc].fc', '9_fc'):
  print('True')
else:
  print('False')
# Out:
# True

# %%
if re.match('b[a-c]*c', 'baaaabaaaac'):
  print('True')
else:
  print('False')
# Out:
# True

# %% [markdown]
# **bold text**. - Period
#
# A period matches any single character (except newline '\n').
#
# ^ - Caret
#
# The caret symbol ^ is used to check if a string starts with a certain character.
#
# $ - Dollar
#
# The dollar symbol $ is used to check if a string ends with a certain character.
#
# \* - Star
#
# The star symbol * matches zero or more occurrences of the pattern left to it.
#
# \+ - Plus
#
# The plus symbol + matches one or more occurrences of the pattern left to it.
#
# ? - Question Mark
#
# The question mark symbol ? matches **zero** or **one** occurrence of the pattern left to it.
#
# {} - Braces
#
# Repition - Consider this code: {n,m}. This means at least n, and at most m repetitions of the pattern left to it.
#
# \| - Alternation
#
# Vertical bar | is used for alternation (or operator).
#
# () - Group
#
# Parentheses () is used to group sub-patterns. For example, (a|b|c)xz match any string that matches either a or b or c followed by xz

# %%
if re.match('[^a-e]+[0-9]$', 'rg98888x'):  #change *, + and ? and learn
  print('True')
else:
  print('False')
# Out:
# False

# %%
if re.match('[a-z]?b', 'dfb'):  #change *, + and ? and learn
  print('True')
else:
  print('False')
# Out:
# False

# %% [markdown]
# Check your understanding?
#
# This RegEx [0-9]{2, 4} matches at least \_\_\_ digits but not more than \_\_\_ digits

# %%
if re.match('a[^a-zA-Z0-9]com', 'aaab'):  #Fix this
  print('True')
else:
  print('False')

# %% [markdown]
# \d - Matches any decimal digit. Equivalent to [0-9]
#
# \D - Matches any non-decimal digit. Equivalent to [^0-9]
#
# \s - Matches where a string contains any whitespace character.
#
# \S - Matches where a string contains any non-whitespace character.
#
# \w - Matches any alphanumeric character (digits and alphabets). Equivalent to [a-zA-Z0-9_]. underscore _ is also considered an alphanumeric character.
#
# \W - Matches any non-alphanumeric character. Equivalent to [^a-zA-Z0-9_]

# %%
if re.match('\W+', '$&*'):  #Fix this
  print('True')
else:
  print('False')
# Out:
# True

# %% [markdown]
# ###Python RegEx
# the module name is re

# %%
import re

# %% [markdown]
# **re.findall()**
# The re.findall() method returns a list of strings containing all matches.

# %%
# Program to extract numbers from a string

import re

string = 'hello today is $ 15th May 2023'
pattern =   '\W+'  #'\d{3,4}'

result = re.findall(pattern, string) 
print(result)
# Out:
# [' ', ' ', ' $ ', ' ', ' ']

# %%
'sai ram,123 iii'.split(',')
# Out:
# ['sai ram', '123 iii']

# %% [markdown]
# **re.split()**
# The re.split method splits the string where there is a match and returns a list of strings where the splits have occurred.

# %%
'hai,hello,bye hai'.split(',')

# %%
import re

string = 'hello today is 12th october 2022a4'
pattern = '\d+|is'

result = re.split(pattern, string) 
print(result)
# Out:
# ['hello today ', ' ', 'th october ', 'a', '']

# %%
s = 'this is U.S.sentence 1. this is sentence 2? this is ssentence 3! this is sentence4.'
result = re.split('[.?!] ' , s)
#result = s.split('.')
print(result)
# Out:
# ['this is U.S.sentence 1', 'this is sentence 2', 'this is ssentence 3', 'this is sentence4.']

# %% [markdown]
# **re.sub()**
#
# The syntax of re.sub() is:
#
# *re.sub(pattern, replace, string)*
#
# The method returns a string where matched occurrences are replaced with the content of replace variable.

# %%
# Program to remove all whitespaces
import re

# multiline string
string = 'flat no 112\
tower 4 \n road    number 7\
kakinada'

# matches all whitespace characters
pattern = '\d+'

# empty string
replace = '$$$$$$'

new_string = re.sub(pattern, replace, string) 
print(new_string)
# Out:
# flat no $$$$$$tower $$$$$$
#  road    number $$$$$$kakinada

# %% [markdown]
# **re.search()**
#
# The re.search() method takes two arguments: a pattern and a string. The method looks for the first location where the RegEx pattern produces a match with the string.
#
# If the search is successful, re.search() returns a match object; if not, it returns None.
#
# *match = re.search(pattern, str)*

# %%
import re

string = "I am learning Data Science at Guvi. Playing with Data is gun"

# check if 'Python' is at the beginning
match = re.search('[Ff]un', string)

if match:
  print("pattern found inside the string")
else:
  print("pattern not found")

# %%
\d{10}

# %% [markdown]
# #PIP
# pip is used to install and manage python packages.
#
# ###What is pip?
# pip is the standard package manager for Python. We can use pip to install additional packages that are not available in the Python standard library.

# %% [markdown]
# pip comes pre-installed on python.
#
# Check whether pip is install on your system or not?

# %%
# !python --version
# Out:
# Python 3.10.11

# %%
pip --version
# Out:
# pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %% [markdown]
# How to use pip?
#
# installing : pip install package-name
#
# uninstall: pip uninstall package-name

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached transformers-4.29.2-py3-none-any.whl (7.1 MB)
# ...

# %%
pip uninstall transformers
# Out:
# Found existing installation: transformers 4.29.2
# Uninstalling transformers-4.29.2:
#   Would remove:
#     /usr/local/bin/transformers-cli
#     /usr/local/lib/python3.10/dist-packages/transformers-4.29.2.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/transformers/*
# Proceed (Y/n)? y
#   Successfully uninstalled transformers-4.29.2

# %%
import numpy

# %%
numpy.abs(10)

# %%
import transformers

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ---------------------
# absl-py                       1.4.0
# alabaster                     0.7.13
# albumentations                1.2.1
# altair                        4.2.2
# anyio                         3.6.2
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# array-record                  0.2.0
# arviz                         0.15.1
# astropy                       5.2.2
# astunparse                    1.6.3
# attrs                         23.1.0
# audioread                     3.0.0
# autograd                      1.5
# Babel                         2.12.1
# backcall                      0.2.0
# beautifulsoup4                4.11.2
# bleach                        6.0.0
# blis                          0.7.9
# blosc2                        2.0.0
# bokeh                         2.4.3
# branca                        0.6.0
# ...

# %% [markdown]
# #How to install a specific package?

# %%
pip install requests==2.21.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.0/58.0 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.8/118.8 kB 12.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.15
#     Uninstalling urllib3-1.26.15:
#       Successfully uninstalled urllib3-1.26.15
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
# ...

# %% [markdown]
# How to check the existing packages?

# %%
pip list

# %% [markdown]
# Getting information about a package...

# %%
pip install numpy

# %%
pip show numpy
# Out:
# Name: numpy
# Version: 1.22.4
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email:
# License: BSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# ...

# %%
pip show transformers
# Out:
# Name: transformers
# Version: 4.29.2
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, tokenizers, tqdm
# Required-by:

# %%
pip show pandas  #show the details of the package

# %% [markdown]
# How to remove a package?

# %%
pip uninstall requests

# %% [markdown]
# ####Requirement files
# A file containing all the package names
# this file can also be used to install python packages in batches.

# %%
pip install -r Requirements.txt

# %% [markdown]
# #Reading data from an excel sheet in *python*

# %%
pip --version

# %%
#to check the installed libraries
pip list

# %%
#removing xlrd package
pip uninstall xlrd

# %%
#installing
# !pip install xlrd==1.2.0

# %%
import xlrd

# %%
#opening a workbook
wb = xlrd.open_workbook("sample.xlsx")

# %%
wb.sheet_names()

# %%
sheet = wb.sheet_by_index(0)

# %%
type(sheet)

# %%
print(sheet.cell_value(0, 1))

# %%
print(sheet.cell_value(2, 3))

# %%
print(sheet.cell_value(1, 1))

# %%
print(sheet.ncols, sheet.nrows)

# %%
#Extracting the column names
for i in range(sheet.ncols):
  print(sheet.cell_value(1,i))

# %%
#printing a particular row
print(sheet.row_values(1))

# %%
print(sheet.row_values(0))

# %%
for i in range(sheet.nrows):
  print(sheet.row_values(i))

# %% [markdown]
# * What is MySQL?
# * What is meant by a database?
# * what is meant by a relation?
# * what is relational database?
# * What is the language of relational database?
# * What are the three important parts of SQL?

# %% [markdown]
# Install MySQL with Mysqlinstaller
#
# from http://dev.mysql.com/downloads/installer/.

# %% [markdown]
# Refer https://www.mysqltutorial.org/getting-started-with-mysql/ to learn the basics of MySQL

# %% [markdown]
# #Iterators

# %%
L = [1, 2, 3, 4]
for x in L:
  print(x)

# %%
# define a list
my_list = [4, 7, 0, 3]

# get an iterator using iter()
my_iter = iter(my_list)

# iterate through it using next()

# Output: 4
print(next(my_iter))

# %%
next(my_iter)

# %%
next(my_iter)

# %%
next(my_iter)

# %%
next(my_iter)

# %% [markdown]
# A more elegant way of automatically iterating is by using the for loop.

# %%
for x in my_list:
  print(x)

# %%
class PowTwo:
    """Class to implement an iterator
    of powers of two"""

    def __init__(self, max=0):
        self.max = max

    def __iter__(self):
        self.n = 0
        return self

    def __next__(self):
        if self.n <= self.max:
            result = 2 ** self.n
            self.n += 1
            return result
        else:
            raise StopIteration


# create an object
numbers = PowTwo(3)

# create an iterable from the object
i = iter(numbers) # numbers.__iter__()

# Using next to get to the next iterator element
print(next(i))
print(next(i))
print(next(i))
print(next(i))
print(next(i))

# %%
L=[1,2,3]

# %%
for x in L:
  print(x, end=" ")

# %%
print(*L)

# %% [markdown]
# #Pickling

# %%
import pickle

# %%
def write():  
    f = open("binarywrite.bin", "wb")
    list = ['CTP', 'Chemistry', 'Maths', 'English', 'EEEE']
    pickle.dump(list, f)
    f.close()
    
def read():
    f = open("binarywrite.bin", "rb")
    L = pickle.load(f)
    print(L)
    f.close()

# %%
write()
print("Data Written successfully")
# Out:
# Data Written successfully

# %%
read()
print("Data read and displayed successfully")
# Out:
# ['CTP', 'Chemistry', 'Maths', 'English', 'EEEE']
# Data read and displayed successfully

# %%
def write():
    f = open("srithan.bin", "wb")
    d = {'name':"Srithan", 'hobbies':['Animation', 'Drawing', 'Watching TV'], 'age':9}
    pickle.dump(d, f)
    f.close()
    
def read():
    f = open("srithan.bin", "rb")
    D = pickle.load(f)
    print(D)
    f.close()

# %%
write()
print("Data Written successfully")
# Out:
# Data Written successfully

# %%
read()
print("Data read and displayed successfully")
# Out:
# {'name': 'Srithan', 'hobbies': ['Animation', 'Drawing', 'Watching TV'], 'age': 9}
# Data read and displayed successfully

# %% [markdown]
# #Python JSON

# %% [markdown]
# JSON (JavaScript Object Notation) is a popular data format used for representing structured data. It's common to transmit and receive data between a server and web application in JSON format.
#
# In Python, JSON exists as a string.
# p = '{"name": "Bob", "languages": ["Python", "Java"]}'
# It's also common to store a JSON object in a file.

# %%
p = '{"name": "Bob", "languages": ["Python", "Java"]}'

# %%
type(p)
# Out:
# str

# %%
#To work with JSON (string, or file containing JSON object), you can use Python's json module.
import json

# %%
#The json module makes it easy to parse JSON strings and files containing JSON object.
#a JSON string can be parsed using json.loads() method. The method returns a dictionary.

import json

person = '{"name": "Bob", "languages": ["English", "French"]}'
person_dict = json.loads(person)

print( person_dict)

print(person_dict['languages'])
# Out:
# {'name': 'Bob', 'languages': ['English', 'French']}
# ['English', 'French']

# %%
type(person_dict)
# Out:
# dict

# %% [markdown]
# You can use json.load() method to read a file containing JSON object.
#
# Suppose, you have a file named person.json which contains a JSON object.

# %%
f = open("person.json","r")
data = json.load(f)


print(data)
# Out:
# {'name': 'Bob', 'languages': ['English', 'French']}

# %%
type(data)
# Out:
# dict

# %%
import json

person_dict = {'name': 'Bob',
'age': 12,
'children': None
}
person_json = json.dumps(person_dict)

# Output: {"name": "Bob", "age": 12, "children": null}
print(person_json)

# %%
type(person_json)

# %%
type(person_dict)

# %%
import json

person_dict = {"name": "Bob",
"languages": ["English", "French"],
"married": True,
"age": 32
}

json_file = open('personnew.json', 'w')
json.dump(person_dict, json_file)

# %%
json_file.close()
